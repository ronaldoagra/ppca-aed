# %%
import csv
import os
from pathlib import Path
import re
import matplotlib.pyplot as plt
import numpy as np

# %%
############## ARQUIVO INCOMPLETO - A FINALIZAR

# recupera o caminho completo do diretório de dados de resultado
dir_dados_resultados = str(Path(os.getcwd()).parents[0]) + '\data\output'

# Apresenta o número de sprints gerador por cada cenário
sprint_por_cenario = {}

# percorre cada arquivo presente no diretório de dados de entrada
for arquivo_resultado in Path(dir_dados_resultados).iterdir():

    if not (arquivo_resultado.is_file() and arquivo_resultado.suffix == '.csv'):
        continue

    algoritmo = 'MIP' if str(arquivo_resultado).find('MIP') != -1 else 'CPSAT'

    try:
        qtd_requisitos = re.search('req-(.+?)\\.csv', str(arquivo_resultado)).group(1)
    except AttributeError:
        qtd_requisitos = ''

    print(algoritmo, '-', qtd_requisitos, ':', arquivo_resultado)

    # lista que armazenará os dados de cada arquivo
    resultados = {}
    valores = []
    pesos = []

    # Inicializa a quantidade de sprints por cenário a cada novo cenário
    if sprint_por_cenario.get(qtd_requisitos) is None:
        sprint_por_cenario[qtd_requisitos] = {'MIP': [], 'CPSAT': []}

    if arquivo_resultado.is_file() and arquivo_resultado.suffix == '.csv':
        # faz a leitura do CSV
        with open(arquivo_resultado, newline='') as csvfile:
            leitor = csv.DictReader(csvfile)
            valor_capacidade = {}

            for linha in leitor:

                # sprint,requisito,valor_req,peso_req
                sprint = linha['sprint']
                valor = float(linha['valor_req'])
                peso = float(linha['peso_req'])
                valor_capacidade = resultados.get(sprint)

                # primeira vez da análise da sprint, cria a chave e insere o valor (valor e peso do requisito)
                if valor_capacidade is None:
                    valor_capacidade = {'valor': 0, 'capacidade': 0}
                    sprint_por_cenario[qtd_requisitos][algoritmo].append({sprint: valor_capacidade})

                valor_capacidade['valor'] += float(linha['valor_req'])
                valor_capacidade['capacidade'] += float(linha['peso_req'])
                resultados[sprint] = valor_capacidade


# print('**', sprint_por_cenario[qtd_requisitos])
# print('**', len(sprint_por_cenario[qtd_requisitos][algoritmo]))
# print(resultados)
# print(sprint_por_cenario)
# sprint_por_cenario[qtd_requisitos][algoritmo] = len(sprint_por_cenario[qtd_requisitos][algoritmo])
# print("Sprints por cenário: ", sprint_por_cenario)
# imprime_resultados_csv(algoritmo, qtd_requisitos, resultados)
# Out:
# CPSAT - 10 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-CPSAT-req-10.csv
# CPSAT - 100 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-CPSAT-req-100.csv
# CPSAT - 200 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-CPSAT-req-200.csv
# CPSAT - 30 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-CPSAT-req-30.csv
# CPSAT - 300 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-CPSAT-req-300.csv
# CPSAT - 400 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-CPSAT-req-400.csv
# CPSAT - 50 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-CPSAT-req-50.csv
# CPSAT - 500 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-CPSAT-req-500.csv
# CPSAT - 70 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-CPSAT-req-70.csv
# MIP - 10 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-MIP-req-10.csv
# MIP - 100 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-MIP-req-100.csv
# MIP - 200 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-MIP-req-200.csv
# MIP - 30 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-MIP-req-30.csv
# MIP - 300 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-MIP-req-300.csv
# MIP - 400 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-MIP-req-400.csv
# MIP - 50 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-MIP-req-50.csv
# MIP - 70 : C:\Users\UnB\OneDrive - unb.br (1)\Mestrado\ppca 2022\AED\workspace\ppca-aed\data\output\resultado-MIP-req-70.csv

# %% [markdown]
# # Tempo de execução

# %%
from pathlib import Path
import os
import csv
import matplotlib.pyplot as plt

arquivo_tempo_execucao = str(Path(os.getcwd()).parents[0]) + '\data\\resultados-tempo-execucao.csv'

with open(arquivo_tempo_execucao, newline='') as csvfile:
    leitor = csv.DictReader(csvfile)

    dados = {'MIP': {'valores':[], 'qtd_requisitos': []}, 'CPSAT':{'valores':[], 'qtd_requisitos': []}}

    for linha in leitor:

        #if not qtd_requisitos.__contains__(linha['Qtd_requisitos']):
        #

        metodo = linha['Metodo']

        if not linha['Tempo_segundos'] == '???':
            dados.get(metodo).get('qtd_requisitos').append(linha['Qtd_requisitos'])
            dados.get(metodo).get('valores').append(float(linha['Tempo_segundos']))

    print(dados)

plt.plot(dados.get('MIP').get('qtd_requisitos'), dados.get('MIP').get('valores'), label = "MIP", linestyle="-")
plt.plot(dados.get('CPSAT').get('qtd_requisitos'), dados.get('CPSAT').get('valores'), label = "MIP", linestyle="-")
plt.legend()
plt.show()
# Out:
# {'MIP': {'valores': [0.010802268981933594, 0.011677265167236328, 0.021634578704833984, 0.027979612350463867, 0.12572240829467773, 0.46387624740600586, 18.08130717277527, 124.2603907585144], 'qtd_requisitos': ['10', '30', '50', '70', '100', '200', '300', '400']}, 'CPSAT': {'valores': [0.02068948745727539, 0.029865264892578125, 0.0635678768157959, 0.0803682804107666, 0.19415664672851562, 0.6900734901428223, 5.940147399902344, 3.170191764831543, 29.614636421203613], 'qtd_requisitos': ['10', '30', '50', '70', '100', '200', '300', '400', '500']}}

# %% [markdown]
# # Sprint por cenário

# %%
barra_mip = []
barra_cpsat = []

# set width of bars
barWidth = 0.25

chaves = sprint_por_cenario.keys()
list1 = [int(x) for x in chaves]
list1.sort()
print(list1)
for cenario in list1:
    barra_mip.append(len(sprint_por_cenario[str(cenario)]['MIP']))
    barra_cpsat.append(len(sprint_por_cenario[str(cenario)]['CPSAT']))
print(barra_mip)
print(barra_cpsat)

# Set position of bar on X axis
br1 = np.arange(len(barra_mip))
br2 = [x + barWidth for x in br1]

# Make the plot
plt.bar(br1, barra_mip, color='r', width=barWidth, edgecolor='grey', label='MIP')
plt.bar(br2, barra_cpsat, color='g', width=barWidth, edgecolor='grey', label='CPSAT')

# Adding Xticks
plt.xlabel('Cenário', fontweight='bold', fontsize=15)
plt.ylabel('#Sprint', fontweight='bold', fontsize=15)
plt.xticks([r + barWidth for r in range(len(list1))], list1)

plt.legend()
plt.show()
# Out:
# [10, 30, 50, 70, 100, 200, 300, 400, 500]
# [2, 4, 8, 9, 15, 28, 40, 55, 0]
# [2, 4, 8, 9, 15, 28, 40, 55, 68]

# %% [markdown]
# # Valor e capacidade por cenário

# %%
# lista os cenários
cenarios = sprint_por_cenario.keys()
list_cenarios = [int(x) for x in cenarios]
list_cenarios.sort()
print(list_cenarios)

for cenario in list_cenarios:

    # set width of bars
    barWidth = 0.35

    cor = 'r'

    # lista com os nomes dos sprints para montar legenda
    list_dados = {'MIP': {'lst_valor': [], 'lst_capacidade': []}, 'CPSAT': {'lst_valor': [], 'lst_capacidade': []}}

    fig, axs = plt.subplots(nrows=2, ncols=1, sharex=True)
    ax = axs[0]
    ax1 = axs[1]
    barras = []

    for nome_algoritmo in list_dados.keys():

        if len(sprint_por_cenario[str(cenario)][nome_algoritmo]) <= 0:
            continue

        # Busca os nomes das sprints para montar a legenda do gráfico
        for chaves in sprint_por_cenario[str(cenario)][nome_algoritmo]:
            nome_sprint = list(chaves.keys())[0]
            dados_sprint = list(chaves.values())[0]
            list_dados[nome_algoritmo]['lst_valor'].append(dados_sprint['valor'])
            list_dados.get(nome_algoritmo)['lst_capacidade'].append(dados_sprint.get('capacidade'))


        # Set position of bar on X axis
        br1 = np.arange(len(list_dados.get(nome_algoritmo)['lst_valor']))

        # if idx // 2 == 0:
        barras.append(ax.bar(br1 + barWidth/2, list_dados.get(nome_algoritmo)['lst_valor'], color=cor, width=0.35,
                   edgecolor='grey', label=nome_algoritmo))

        # capacidade
        br2 = np.arange(len(list_dados.get(nome_algoritmo)['lst_capacidade']))
        barras.append(ax1.bar(br1 + barWidth / 2, list_dados.get(nome_algoritmo)['lst_capacidade'], color=cor, width=0.35,
                             edgecolor='grey', label=nome_algoritmo))
        if cor == 'r':
            cor = 'b'
        # incrementa o distanciamento entre barras
        barWidth += 0.70

        # labels =
    #ax.set_xticks(br1)
    #ax.set_xticklabels(br1+1)
    #ax.legend()
    ax.set_ylabel('Valor')
    #ax.set_xlabel(str(cenario))
    ax.set_title('Valor entregue por Sprint')

    ax1.set_xticks(br1)
    ax1.set_xticklabels(br1 + 1)
    ax1.legend()
    ax1.set_ylabel('Capacidade')
    label= 'Cenário: '+str(cenario)
    ax1.set_xlabel(label)
    ax1.set_title('Capacidade por Sprint')

    def autolabel(rects, x):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            x.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')


    if len(barras)>2:
        autolabel(barras[0], ax)
        autolabel(barras[1], ax1)
        autolabel(barras[2], ax)
        autolabel(barras[3], ax1)
    else:
        autolabel(barras[0], ax)
        autolabel(barras[1], ax)

   # fig.tight_layout()
    fig.set_figwidth(30)
    fig.set_figheight(20)

    plt.show()
# Out:
# [10, 30, 50, 70, 100, 200, 300, 400, 500]
